# %% [markdown]
# **CSVにて保存したフォロワーリストを確認する**

# %%
import pandas as pd

# %%
account_name = "ryusuke__h"

# %%
df = pd.read_csv(f"./output/@{account_name}_mutual_followers.csv")

# %%
df.shape
# Out:
# (640, 2)

# %%
df.head(30)
# Out:
#             followers               id
# 0                2bit          2bitpng
# 1            fujikaWA        fujika_WA
# 2               あさりんご   morningapple99
# 3               tombo      tombo_choco
# 4             akihiro   akihiroyama_it
# 5   福井大学競技プログラミングサークル       uf_atcoder
# 6    茶ちゅう #BFS,DFS頑張る       kyopurochu
# 7                 ちゃば          tyaba55
# 8                  かべ         kabe_239
# 9           recta_002        recta_002
# 10          yassu@N=1        yassu0320
# 11             しんほ ゛🦕        saurus_kp
# 12               ミケサメ         mike_ngc
# 13              yadon        Seipann11
# 14               #Kさん   fuutyoukagetsu
# 15            take000     gaming_linux
# 16           CapoCapo           cpbm_p
# 17                しげる     shigeru_0414
# 18           atma株式会社         atma_inc
# 19         nyker_goto       nyker_goto
# 20              ころんびあ        colum2131
# 21          kobanzame    kobanzame_313
# 22        武島（paiza人事）     paizaHR_take
# ...

# %%
df.tail(30)
# Out:
#                       followers               id
# 610                         ntk         ntk_ta01
# 611                      チョモノリス       chomonolis
# 612                        Kota    kota0501_orca
# 613                      haruki      haruki_4936
# 614                  otamay@競プロ          otamay6
# 615       ゆうっうっう🛸@ 多次元配列は一次元に直す     yuusanlondon
# 616                        regi        Re_code_A
# 617       remono@水coder良問13/100       remono1031
# 618                      8wings         8wings64
# 619                         かえで       kaede20203
# 620                       カルピス💊          wkrps_v
# 621                         Nはら         N___hara
# 622                          SF   School_Flag734
# 623                 綾瀬 / aya_se      Hakuba_snow
# 624                        そらいえ          soraie_
# 625                      まどれーぬ🍫     madoreenu314
# 626                         S_K   watasihakodama
# 627             nico_shindannin  nico_shindannin
# ...
